# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"

import pandas as pd

df = pd.read_csv(url, sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['alcohol'], df['quality'])
plt.xlabel("Alcohol")
plt.ylabel("Quality")
plt.title("Alcohol vs Wine Quality")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df['alcohol'], bins=20)
plt.title("Distribution of Alcohol Content")
plt.xlabel("Alcohol")
plt.ylabel("Frequency")
plt.show()

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
Q1 = df['alcohol'].quantile(0.25)
Q3 = df['alcohol'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower Bound:", lower)
print("Upper Bound:", upper)
# Out:
# Lower Bound: 7.1000000000000005
# Upper Bound: 13.5

# %%
df_no_outliers = df[(df['alcohol'] >= lower) & (df['alcohol'] <= upper)]

df_no_outliers.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_sample = df.sample(frac=0.5)

df_sample.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1193            6.4             0.885         0.00             2.3      0.166
# 1213            9.6             0.380         0.42             1.9      0.071
# 382             8.3             0.260         0.42             2.0      0.080
# 1424            8.3             0.260         0.37             1.4      0.076
# 1586            7.5             0.310         0.41             2.4      0.065
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1193                  6.0                  12.0  0.99551  3.56       0.51
# 1213                  5.0                  13.0  0.99659  3.15       0.75
# 382                  11.0                  27.0  0.99740  3.21       0.80
# 1424                  8.0                  23.0  0.99740  3.26       0.70
# 1586                 34.0                  60.0  0.99492  3.34       0.85
#
#       alcohol  quality
# 1193     10.8        5
# ...

# %%
df_reduced = df.drop(columns=['citric acid'])

df_reduced.head()
# Out:
#    fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0            7.4              0.70             1.9      0.076
# 1            7.8              0.88             2.6      0.098
# 2            7.8              0.76             2.3      0.092
# 3           11.2              0.28             1.9      0.075
# 4            7.4              0.70             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df['alcohol_scaled'] = scaler.fit_transform(df[['alcohol']])

df[['alcohol', 'alcohol_scaled']].head()
# Out:
#    alcohol  alcohol_scaled
# 0      9.4        0.153846
# 1      9.8        0.215385
# 2      9.8        0.215385
# 3      9.8        0.215385
# 4      9.4        0.153846

# %%
df['alcohol_category'] = pd.cut(df['alcohol'],
                               bins=3,
                               labels=["Low","Medium","High"])

df[['alcohol','alcohol_category']].head()
# Out:
#    alcohol alcohol_category
# 0      9.4              Low
# 1      9.8              Low
# 2      9.8              Low
# 3      9.8              Low
# 4      9.4              Low

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
print("Minimum:", df['alcohol'].min())
print("Maximum:", df['alcohol'].max())
print("Mean:", df['alcohol'].mean())
print("Median:", df['alcohol'].median())
print("Mode:", df['alcohol'].mode()[0])
# Out:
# Minimum: 8.4
# Maximum: 14.9
# Mean: 10.422983114446529
# Median: 10.2
# Mode: 9.5

# %%
data_range = df['alcohol'].max() - df['alcohol'].min()
print("Range:", data_range)
print("Q1:", df['alcohol'].quantile(0.25))
print("Q2 (Median):", df['alcohol'].quantile(0.5))
print("Q3:", df['alcohol'].quantile(0.75))
print("IQR:", df['alcohol'].quantile(0.75) - df['alcohol'].quantile(0.25))
print("Variance:", df['alcohol'].var())
print("Std Dev:", df['alcohol'].std())
# Out:
# Range: 6.5
# Q1: 9.5
# Q2 (Median): 10.2
# Q3: 11.1
# IQR: 1.5999999999999996
# Variance: 1.1356473950004737
# Std Dev: 1.0656675818473946

# %%
correlation = df.corr(numeric_only=True)

correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
# alcohol_scaled            -0.061668         -0.202288     0.109903
#
# ...

# %% [markdown]
# Name: Reza Shrestha
# Course: MSCS 634
# Lab: Data Visualization and Statistical Analysis
